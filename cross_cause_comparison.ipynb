# %% [markdown]
# ## Cross-Cause Comparison & Risk Aversion Analysis

# %% [markdown]
# ### Set-up

# %%
from squigglepy.numbers import K, M, B
import interventions.chickens as chickens
import interventions.shrimp as shrimp
import interventions.xrisk as xrisk
import interventions.low_risk_ghd as low_risk_ghd
import interventions.road_safety as road_safety
import helper_functions.utils as utils
import helper_functions.dmreu_calibration as dmreu_calibration
import squigglepy as sq
import numpy as np

money = 100*M
N = 8*M

# %% [markdown]
# ### Simulate Cost-Effectiveness Estimates for Each Cause Area

# %% [markdown]
# #### Shrimp

# %%
harms_list = ['high_density', 'ammonia', 'lack_substrate', 'low_dissolved_oxygen', \
                'low_salinity', 'water_based_transit', 'ph', 'underfeeding', 'high_temp', \
                'water_pollution', 'harvest', 'low_temp', 'malnutrition', 'predators', \
                'slaughter', 'waterless_transit', 'eyestalk_ablation']

import importlib
importlib.reload(shrimp)
importlib.reload(utils)

stunning_shrimp_project = {
    'harm_types': ['slaughter', 'harvest'],
    'low_suffering_reduced_proportion': {'slaughter': 0.5, 'harvest': 0.5}, # low end on proportion of shrimp suffering reduced by intervention
    'high_suffering_reduced_proportion': {'slaughter': 0.9, 'harvest': 0.9}, # high end on proportion of shrimp suffering reduced by intervention
    'low_p_success': 0.3, # low end on probability of intervention succeeding
    'high_p_success': 0.8, # high end on probability of intervention succeeding
    'low_p_shrimp_affected': 10**-4, # low end on proportion of shrimp in world affected by an individual campaign
    'high_p_shrimp_affected': 10**-3, # high end on proportion of shrimp being affected by an individual campaign
    'low_cost': 100*K, # low end on cost of intervention
    'high_cost': 500*K, # high end on cost of intervention
    'low_yrs_credit': 2, # low end on years of credit for intervention
    'high_yrs_credit': 10, # high end on years of credit for intervention
    }

shrimp_stunning_human_dalys_per_1000 = shrimp.shrimp_campaign_human_dalys_per_1000(stunning_shrimp_project, to_print=True)

nh3_shrimp_project = {
    'harm_types': ['ammonia'],
    'low_suffering_reduced_proportion': {'ammonia': 0.3,}, # low end on proportion of shrimp suffering reduced by intervention
    'high_suffering_reduced_proportion': {'ammonia': 0.7, }, # high end on proportion of shrimp suffering reduced by intervention
    'low_p_success': 0.3, # low end on probability of intervention succeeding
    'high_p_success': 0.8, # high end on probability of intervention succeeding
    'low_p_shrimp_affected': 10**-4, # low end on proportion of shrimp in world affected by an individual campaign
    'high_p_shrimp_affected': 10**-3, # high end on proportion of shrimp being affected by an individual campaign
    'low_cost': 100*K, # low end on cost of intervention
    'high_cost': 500*K, # high end on cost of intervention
    'low_yrs_credit': 2, # low end on years of credit for intervention
    'high_yrs_credit': 10, # high end on years of credit for intervention
    }

shrimp_sc_stunning_human_daly_burden = shrimp.get_human_daly_burden_from_harm_type(stunning_shrimp_project, to_print=True)
shrimp_sc_nh3_human_daly_burden = shrimp.get_human_daly_burden_from_harm_type(nh3_shrimp_project, to_print=True)

shrimp_stunning_sentience_conditioned_human_dalys_per_1000 = shrimp.shrimp_sentience_conditioned_human_dalys_per_1000(stunning_shrimp_project, to_print=True)
shrimp_nh3_sentience_conditioned_human_dalys_per_1000 = shrimp.shrimp_sentience_conditioned_human_dalys_per_1000(nh3_shrimp_project, to_print=True)

shrimp_nh3_human_dalys_per_1000 = shrimp.shrimp_campaign_human_dalys_per_1000(nh3_shrimp_project, to_print=True)
# Out:
# 100%|██████████| 2/2 [00:06<00:00,  3.26s/it]
# 100%|██████████| 8000000/8000000 [00:08<00:00, 963951.90it/s]
# 100%|██████████| 2/2 [00:05<00:00,  2.92s/it]
# 100%|██████████| 8000000/8000000 [00:06<00:00, 1170802.39it/s]
# Mean human-DALYs per 1000 shrimp: 37.69790617448776
# Percentiles:
# {1: 0.0, 5: 0.0, 10: 0.0, 20: 0.0, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 3.3878921620140527, 80: 13.826092066793578, 90: 54.997456964493644, 95: 144.05321460007474, 99: 699.1938414407812}
# Mean sentience-conditioned annual human-DALY burden: 27544163.43213415
# Percentiles:
# {1: 129972.9084889247, 5: 421355.9365752162, 10: 788019.9925720837, 20: 1680251.480967888, 30: 2901452.571339714, 40: 4632866.706613474, 50: 7176252.292888362, 60: 11106391.555071665, 70: 17735062.068355195, 80: 30695054.73976701, 90: 65645300.77959814, 95: 121231388.32103899, 99: 323012863.8535003}
# Mean shrimp-daly burden by harms: 62141215.997377045
# Percentiles:
# {1: 12727518.171845509, 5: 18832260.680523712, 10: 23233113.800032955, 20: 30066026.28119199, 30: 36297577.81207356, 40: 42733077.06324775, 50: 49852139.678919464, 60: 58286357.34213715, 70: 69113158.6898823, 80: 84728702.69096664, 90: 113377800.67740221, 95: 145501348.75572464, 99: 238582260.1240533}
# Mean total sentience-conditioned human DALY burden over 2-10 year speed up: 138736357.05899906
# Percentiles:
# {1: 497739.2551577366, 5: 1684463.061822987, 10: 3226178.322695471, 20: 7093002.408868326, 30: 12516263.077815583, 40: 20358231.341124546, 50: 32081005.958872005, 60: 50544741.369720995, 70: 82212165.71294466, 80: 145242384.7048642, 90: 319039196.0446961, 95: 599731459.9273801, 99: 1728450309.4153593}
# Mean sentience-conditioned annual human-DALY burden: 1579210518.4008362
# Percentiles:
# {1: 400935.1222650013, 5: 2050295.083393466, 10: 4893936.807488046, 20: 14011987.897727821, 30: 29945277.85059496, 40: 57254763.85232943, 50: 104880173.36872548, 60: 192193176.86507773, 70: 366852518.28126603, 80: 780722434.469583, 90: 2209840401.9875536, 95: 5161037666.522601, 99: 24703639409.84481}
# Mean shrimp-daly burden by harms: 3546409417.258055
# Percentiles:
# {1: 12144280.283413844, 5: 40588902.43695265, 10: 77101190.46904722, 20: 167683278.19510064, 30: 293604210.68006957, 40: 474197154.30509144, 50: 741960237.7428076, 60: 1161752518.617896, 70: 1875913694.867235, 80: 3290195677.1306715, 90: 7173352605.515163, 95: 13644611140.768457, 99: 45421460710.7316}
# Mean total sentience-conditioned human DALY burden over 2-10 year speed up: 7957931578.025186
# Percentiles:
# {1: 1599028.2489843564, 5: 8446452.608756393, 10: 20547416.932587557, 20: 60098298.453029275, 30: 130456951.59986638, 40: 252835597.5817597, 50: 468881637.8657286, 60: 869454376.184686, 70: 1682474692.5519238, 80: 3636422115.365397, 90: 10528602384.728373, 95: 25086683570.68894, 99: 124449331156.76297}
# 100%|██████████| 2/2 [00:05<00:00,  2.98s/it]
# 100%|██████████| 8000000/8000000 [00:07<00:00, 1081245.88it/s]
# 100%|██████████| 2/2 [00:06<00:00,  3.40s/it]
# 100%|██████████| 8000000/8000000 [00:12<00:00, 664395.90it/s]
# Mean number of shrimp helped per dollar: 5145.864293649329
# Percentiles:
# {1: 253.66996360894152, 5: 521.327011672887, 10: 765.0094291901246, 20: 1216.6202600361946, 30: 1699.576662529728, 40: 2260.561447203968, 50: 2953.4929703292173, 60: 3858.059470428203, 70: 5136.231626955175, 80: 7173.323272771407, 90: 11397.85375231524, 95: 16724.68499235088, 99: 34254.46335980498}
# Mean sentience-conditioned Shrimp-DALYs per $1000: 212.03522739883454
# Percentiles:
# {1: -16.703261274936917, 5: 9.870070517014911, 10: 18.211553558952154, 20: 33.71627620871029, 30: 51.00677988536293, 40: 72.04775414244644, 50: 99.0202888544541, 60: 135.74567275354082, 70: 190.01286775385725, 80: 281.34289424780474, 90: 484.603498346148, 95: 759.9325172245448, 99: 1775.6396550617326}
# Mean sentience-conditioned welfare range for shrimp: 0.4435035528611835
# Mean sentience-conditioned human-DALYs per $1000: 93.97013528274253
# percentiles
# {1: -2.0657933648371927, 5: 0.324609516242552, 10: 0.8507027922286461, 20: 2.3141993581754567, 30: 4.575014456985202, 40: 8.09066894022622, 50: 13.700773478886738, 60: 23.095737697853266, 70: 40.246589858086004, 80: 76.90526059174535, 90: 186.61449956816, 95: 381.7789304936096, 99: 1373.159239551636}
# 100%|██████████| 2/2 [00:10<00:00,  5.22s/it]
# 100%|██████████| 8000000/8000000 [00:17<00:00, 462815.42it/s]
# Mean number of shrimp helped per dollar: 5145.722048526768
# Percentiles:
# {1: 253.92595202022497, 5: 521.3966073075381, 10: 764.9842778068173, 20: 1216.3904455931688, 30: 1699.974617852839, 40: 2261.5038541871168, 50: 2954.299050557802, 60: 3859.1979399049737, 70: 5134.663286642741, 80: 7171.159050339816, 90: 11399.347367419896, 95: 16711.04993522334, 99: 34324.542358868865}
# Mean sentience-conditioned Shrimp-DALYs per $1000: 8412.894696057201
# Percentiles:
# {1: -1285.6429313119852, 5: 15.752413337370852, 10: 52.09793962454806, 20: 153.85005076072605, 30: 314.03004157061315, 40: 566.2264103241519, 50: 973.7182080493674, 60: 1665.3647867271977, 70: 2943.9731255764664, 80: 5718.23506094884, 90: 14299.435602661839, 95: 30431.51074929069, 99: 124506.0985145105}
# Mean sentience-conditioned welfare range for shrimp: 0.4428306660281115
# Mean sentience-conditioned human-DALYs per $1000: 3668.1954447767152
# percentiles
# {1: -232.17066167407438, 5: 0.7146727175206051, 10: 3.2801270642738745, 20: 12.975496212301532, 30: 32.04671230207291, 40: 67.66007092544709, 50: 134.50068916927975, 60: 265.577991960706, 70: 546.5353117412575, 80: 1264.877222650623, 90: 3997.43653719588, 95: 10260.029055556985, 99: 58252.51528153776}
# 100%|██████████| 2/2 [00:11<00:00,  5.85s/it]
# 100%|██████████| 8000000/8000000 [00:12<00:00, 633104.20it/s]
# Mean human-DALYs per 1000 shrimp: 1475.9642960981957
# Percentiles:
# {1: -6.3026259338815125, 5: 0.0, 10: 0.0, 20: 0.0, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 21.66111507191414, 80: 136.23193006157427, 90: 818.7301965851553, 95: 2857.354831885708, 99: 23105.75803174204}

# %% [markdown]
# ### X-Risk Interventions (with Optimistic and Conservative Parameters)

# %% [markdown]
# #### Near-term "Conservative" Intervention

# %%
def bp_to_decimal(bp):
    return bp/10000

# Low-risk intervention with near-term counterfactual credit
nt_conservative_xrisk_intervention = {'p_has_effect': 0.8, 
                    'p_good_if_effect': 0.8, 
                    'low_extent_of_negative_effect': 0.05, 
                    'high_extent_of_negative_effect': 0.3, 
                    'low_years_credit': 100, 
                    'high_years_credit': 1000, 
                    'low_amt_risk_reduced_per_B': bp_to_decimal(0.5), 
                    'high_amt_risk_reduced_per_B': bp_to_decimal(5),
                    'cost': 100*M,
                    'low_years_between_events_killing_3M': 129,
                    'high_years_between_events_killing_3M': 523,}

nt_conservative_xrisk_dalys_per_1000, nt_conservative_risk_reduction_vector, nt_conservative_credit_e_reduction_risk, nt_conservative_credit_p_save_world, \
    nt_conservative_p_end_world, nt_conservative_dalys_at_stake, nt_conservative_expected_dalys_saved_per_1000 = xrisk.get_dalys_saved_per_1000(nt_conservative_xrisk_intervention, to_print=True)
# Out:
# Mean effect multiplier: 0.6169285189851265
# Percentiles:
# {1: -0.2827150807603569, 5: -0.16001489363853613, 10: -0.10313567468198978, 20: 0.0, 30: 0.0, 40: 1.0, 50: 1.0, 60: 1.0, 70: 1.0, 80: 1.0, 90: 1.0, 95: 1.0, 99: 1.0}
# Mean years credit: 189.4805517651715
# Percentiles:
# {1: 10.0, 5: 99.96724087057345, 10: 199.60940479921868, 20: 200.0, 30: 200.0, 40: 200.0, 50: 200.0, 60: 200.0, 70: 200.0, 80: 200.0, 90: 200.0, 95: 200.0, 99: 200.0}
# 3M to 30M
# Mean pre-intervention annual probability of event: 0.0030022961770926203
# Mean pre-intervention cumulative probability of event: 0.41272925702607194
# Mean post-intervention annual probability of event: 0.002997625087267066
# Mean post-intervention cumulative probability of event: 0.41227316365836564
# Mean decrease in cumulative probability of event: 0.000456093367706396
# Percentiles:
# {1: -0.000255754075661806, 5: -0.00011534926993386763, 10: -6.157516137239583e-05, 20: 0.0, 30: 0.0, 40: 0.00024088139321902792, 50: 0.0004170495978744193, 60: 0.0005453076116121335, 70: 0.000679962415064761, 80: 0.0008490386819249185, 90: 0.0011188889805421765, 95: 0.0013838275434252699, 99: 0.0020255949815776563}
# 30M to 300M
# Mean pre-intervention annual probability of event: 0.00084946824193225
# Mean pre-intervention cumulative probability of event: 0.14591470787792377
# Mean post-intervention annual probability of event: 0.0008481475764836923
# Mean post-intervention cumulative probability of event: 0.14570938148940993
# Mean decrease in cumulative probability of event: 0.00020532638851376663
# Percentiles:
# {1: -0.00012095535999300022, 5: -5.113019194257773e-05, 10: -2.5818669572230667e-05, 20: 0.0, 30: 0.0, 40: 8.60360905948543e-05, 50: 0.00016489145688736162, 60: 0.00022605485650264434, 70: 0.0002929710730614321, 80: 0.000380128411083125, 90: 0.0005247237043465193, 95: 0.0006725626319535492, 99: 0.0010448966179556379}
# 300M to 3B
# Mean pre-intervention annual probability of event: 0.0002498905596755157
# Mean pre-intervention cumulative probability of event: 0.04586705230600413
# Mean post-intervention annual probability of event: 0.00024982831747670514
# Mean post-intervention cumulative probability of event: 0.04585598718896902
# Mean decrease in cumulative probability of event: 1.1065117035170043e-05
# Percentiles:
# {1: -7.382071323371875e-06, 5: -2.5134581118746445e-06, 10: -1.0753209284342092e-06, 20: 0.0, 30: 0.0, 40: 2.558269798624835e-06, 50: 5.939889869910342e-06, 60: 9.176374419261888e-06, 70: 1.3191229141462645e-05, 80: 1.903670275187342e-05, 90: 3.010705529598035e-05, 95: 4.2887715622685884e-05, 99: 8.055166634238975e-05}
# Number 3M to 30M where difference made: 3851.0
# Number 30M to 300M where difference made: 1794.0
# Number 300M to 3B where difference made: 111.0
# Total 3M to 30M prevented 3719.0
# Total 30M to 300M prevented 1719.0
# Total 300M to 3B prevented 107.0
# Total 3M to 30M caused 132.0
# Total 30M to 300M caused 75.0
# Total 300M to 3B caused 4.0
# Mean lives saved non-xrisk: 43302.762627976466
# Percentiles: {1: 0.0, 5: 0.0, 10: 0.0, 20: 0.0, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.0, 90: 0.0, 95: 0.0, 99: 0.0}
# Mean DALYs saved approx if prevent risk: 4366720489949.134
# Expected DALYs saved: 56149887.104238436
# Percentiles Expected DALYs saved: {1: -36950105.03135873, 5: -13013099.900444683, 10: -5652001.185746903, 20: 0.0, 30: 0.0, 40: 12263354.96821635, 50: 31534945.556655142, 60: 48695095.00876401, 70: 69320987.92315955, 80: 98711893.44574632, 90: 152862004.65104204, 95: 214318503.3166985, 99: 389397108.2314058}
# Prop. time intervention affects risk: 0.799894625
# Mean effect size (per $100000000 spent): 1.2463906603625691e-05
# Mean absolute effect size: 1.338589889987392e-05
# Approx number makes a difference: 107.08719119899136
# Obeserved number makes a difference: 129.0
# Chance prevents extinction: 0.0015125%
# Chance causes extinction: 0.0001%
# Chance make a difference: 0.0016125%
# AVG DALYs saved (per $100000000 spent):
# Avg. DALYs saved per $1000: 634.9327990280964
# Percentiles:
# [-3.66938935e+05 -1.55690767e+04  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.44743218e+04  3.03193323e+07]
# Expected DALYs saved per $1000: 561.4988710423854
# Percentiles:
# [-5557.62006247 -3512.4503167  -1960.500128    -954.48006
#   -369.5         -130.13         315.35        2143.1805
#   3893.9702      7422.57026    12394.240021   18812.32021319]

# %% [markdown]
# #### Near-Term "Risky" Intervention

# %%
## Riskier near-term impact intervention
nt_risky_xrisk_intervention = {'p_has_effect': 0.5, 
                    'p_good_if_effect': 0.55, 
                    'low_extent_of_negative_effect': 0.3, 
                    'high_extent_of_negative_effect': 1.0, 
                    'low_years_credit': 100, 
                    'high_years_credit': 1000, 
                    'low_amt_risk_reduced_per_B': bp_to_decimal(5), 
                    'high_amt_risk_reduced_per_B': bp_to_decimal(50),
                    'cost': 100*M,
                    'low_years_between_events_killing_3M': 129,
                    'high_years_between_events_killing_3M': 523,} 

nt_risky_xrisk_dalys_per_1000, nt_risky_risk_reduction_vector, nt_risky_e_reduction_risk, nt_risky_p_save_world, \
    nt_risky_p_end_world, nt_risky_dalys_at_stake, nt_risky_expected_dalys_saved_per_1000 = xrisk.get_dalys_saved_per_1000(nt_risky_xrisk_intervention, to_print=True)
# Out:
# Mean effect multiplier: 0.145034523264887
# Percentiles:
# {1: -1.0, 5: -0.7245362806219116, 10: -0.5764989909896342, 20: -0.35058566865419105, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 1.0, 90: 1.0, 95: 1.0, 99: 1.0}
# Mean years credit: 189.48429446297106
# Percentiles:
# {1: 10.0, 5: 100.0509186428808, 10: 199.29769330939936, 20: 200.0, 30: 200.0, 40: 200.0, 50: 200.0, 60: 200.0, 70: 200.0, 80: 200.0, 90: 200.0, 95: 200.0, 99: 200.0}
# 3M to 30M
# Mean pre-intervention annual probability of event: 0.003003505848638456
# Mean pre-intervention cumulative probability of event: 0.4128883005815229
# Mean post-intervention annual probability of event: 0.003002407607569256
# Mean post-intervention cumulative probability of event: 0.41278098995843227
# Mean decrease in cumulative probability of event: 0.00010731062309093662
# Percentiles:
# {1: -0.0010306231729151805, 5: -0.0005783704775039755, 10: -0.00038701484126367757, 20: -0.00014710043601733335, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.00046193655801254343, 90: 0.0007872595980260469, 95: 0.0010598696881826185, 99: 0.0016817400778182385}
# 30M to 300M
# Mean pre-intervention annual probability of event: 0.0008497052722352753
# Mean pre-intervention cumulative probability of event: 0.14595713212011707
# Mean post-intervention annual probability of event: 0.000849395098682997
# Mean post-intervention cumulative probability of event: 0.14590889900276274
# Mean decrease in cumulative probability of event: 4.823311735430675e-05
# Percentiles:
# {1: -0.0005048865127530733, 5: -0.0002630984251030477, 10: -0.00016746740204603983, 20: -5.630180207287782e-05, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.00018596762122791158, 90: 0.00034759812612695807, 95: 0.0004930353370363405, 99: 0.0008446900346746378}
# 300M to 3B
# Mean pre-intervention annual probability of event: 0.00024993243063928467
# Mean pre-intervention cumulative probability of event: 0.045873940752806285
# Mean post-intervention annual probability of event: 0.00024991778597064013
# Mean post-intervention cumulative probability of event: 0.045871337872028205
# Mean decrease in cumulative probability of event: 2.602880778063727e-06
# Percentiles:
# {1: -3.327757213358318e-05, 5: -1.3899782882093036e-05, 10: -7.652727738660658e-06, 20: -1.876106910470021e-06, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 7.009704565219544e-06, 90: 1.6805216061754902e-05, 95: 2.754569201277035e-05, 99: 5.934509369114769e-05}
# Number 3M to 30M where difference made: 2459.0
# Number 30M to 300M where difference made: 1115.0
# Number 300M to 3B where difference made: 69.0
# Total 3M to 30M prevented 1683.0
# Total 30M to 300M prevented 741.0
# Total 300M to 3B prevented 49.0
# Total 3M to 30M caused 776.0
# Total 30M to 300M caused 374.0
# Total 300M to 3B caused 20.0
# Mean lives saved non-xrisk: 9818.460907330069
# Percentiles: {1: 0.0, 5: 0.0, 10: 0.0, 20: 0.0, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.0, 90: 0.0, 95: 0.0, 99: 0.0}
# Mean DALYs saved approx if prevent risk: 4365248672445.576
# Expected DALYs saved: 128264241.74207343
# Percentiles Expected DALYs saved: {1: -1628692996.7691379, 5: -696372765.643642, 10: -384984421.4289453, 20: -85531304.43684441, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 345770725.8887985, 90: 848210511.3581012, 95: 1376979273.261961, 99: 2882300733.4402604}
# Prop. time intervention affects risk: 0.5000155
# Mean effect size (per $100000000 spent): 2.930144424565456e-05
# Mean absolute effect size: 8.172344716790172e-05
# Approx number makes a difference: 653.7875773432138
# Obeserved number makes a difference: 670.0
# Chance prevents extinction: 0.0057375%
# Chance causes extinction: 0.0026375%
# Chance make a difference: 0.008375%
# AVG DALYs saved (per $100000000 spent):
# Avg. DALYs saved per $1000: 1420.1684592952831
# Percentiles:
# [-8.79749165e+07 -5.07930115e+07 -6.25397093e+03  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  4.61411462e+04  6.58350441e+07]
# Expected DALYs saved per $1000: 1282.6424174207357
# Percentiles:
# [-170993.1669186 -107118.1720557  -66185.021945   -36305.83004
#   -16286.9301      -6963.73            0.          13769.791
#    28823.0102      59218.59164    104237.610282   164684.7503207]

# %% [markdown]
# #### Longterm "Conservative" Intervention

# %%
def bp_to_decimal(bp):
    return bp/10000
# Project with longer-term impact but less risk
lt_conservative_xrisk_intervention = {'p_has_effect': 0.8, 
                    'p_good_if_effect': 0.8, 
                    'low_extent_of_negative_effect': 0.05, 
                    'high_extent_of_negative_effect': 0.3, 
                    'low_years_credit': 10*K, 
                    'high_years_credit': 100*K, 
                    'low_amt_risk_reduced_per_B': bp_to_decimal(0.5), 
                    'high_amt_risk_reduced_per_B': bp_to_decimal(5),
                    'cost': 100*M,
                    'low_years_between_events_killing_3M': 129,
                    'high_years_between_events_killing_3M': 523,}

lt_conservative_xrisk_dalys_per_1000, lt_conservative_risk_reduction_vector, lt_conservative_e_reduction_risk, lt_conservative_p_save_world, \
    lt_conservative_p_end_world, lt_conservative_dalys_at_stake, lt_conservative_expected_dalys_saved_per_1000 = xrisk.get_dalys_saved_per_1000(lt_conservative_xrisk_intervention, to_print=True)
# Out:
# Mean effect multiplier: 0.6172455626228242
# Percentiles:
# {1: -0.2826252775451129, 5: -0.1596217747562284, 10: -0.10288282252059175, 20: 0.0, 30: 0.0, 40: 1.0, 50: 1.0, 60: 1.0, 70: 1.0, 80: 1.0, 90: 1.0, 95: 1.0, 99: 1.0}
# Mean years credit: 200.0
# Percentiles:
# {1: 200.0, 5: 200.0, 10: 200.0, 20: 200.0, 30: 200.0, 40: 200.0, 50: 200.0, 60: 200.0, 70: 200.0, 80: 200.0, 90: 200.0, 95: 200.0, 99: 200.0}
# 3M to 30M
# Mean pre-intervention annual probability of event: 0.003003104531706095
# Mean pre-intervention cumulative probability of event: 0.43359581952424037
# Mean post-intervention annual probability of event: 0.0029984356985373515
# Mean post-intervention cumulative probability of event: 0.43312013460196014
# Mean decrease in cumulative probability of event: 0.000475684922279031
# Percentiles:
# {1: -0.00026135691908307557, 5: -0.00011923132823403182, 10: -6.504940234932643e-05, 20: 0.0, 30: 0.0, 40: 0.0002982749672418184, 50: 0.0004481935415516225, 60: 0.0005715512337482797, 70: 0.0007040694836068392, 80: 0.0008719993953030026, 90: 0.0011411567919503596, 95: 0.0014075984919335147, 99: 0.0020482418249188282}
# 30M to 300M
# Mean pre-intervention annual probability of event: 0.0008495836183264202
# Mean pre-intervention cumulative probability of event: 0.153807232210047
# Mean post-intervention annual probability of event: 0.0008482612928621056
# Mean post-intervention cumulative probability of event: 0.15359091704651198
# Mean decrease in cumulative probability of event: 0.00021631516353459192
# Percentiles:
# {1: -0.0001247472690341822, 5: -5.3338062040059196e-05, 10: -2.7685737596072622e-05, 20: 0.0, 30: 0.0, 40: 0.00011281046106712545, 50: 0.00018128785161281025, 60: 0.00024063762818087308, 70: 0.00030724430680750814, 80: 0.00039459236631167466, 90: 0.000540727775494987, 95: 0.0006902296307582046, 99: 0.0010655529901598935}
# 300M to 3B
# Mean pre-intervention annual probability of event: 0.00024989259625893343
# Mean pre-intervention cumulative probability of event: 0.0483897239446009
# Mean post-intervention annual probability of event: 0.00024983029418050687
# Mean post-intervention cumulative probability of event: 0.04837804453020564
# Mean decrease in cumulative probability of event: 1.1679414395161272e-05
# Percentiles:
# {1: -7.650704401294116e-06, 5: -2.650227466022281e-06, 10: -1.1684642309939264e-06, 20: 0.0, 30: 0.0, 40: 3.46118497878134e-06, 50: 6.680799839231533e-06, 60: 9.939107588241566e-06, 70: 1.4022172078698154e-05, 80: 1.9990579700213122e-05, 90: 3.13065719709571e-05, 95: 4.440816280950054e-05, 99: 8.276119130895429e-05}
# Number 3M to 30M where difference made: 4012.0
# Number 30M to 300M where difference made: 1851.0
# Number 300M to 3B where difference made: 97.0
# Total 3M to 30M prevented 3867.0
# Total 30M to 300M prevented 1788.0
# Total 300M to 3B prevented 93.0
# Total 3M to 30M caused 145.0
# Total 30M to 300M caused 63.0
# Total 300M to 3B caused 4.0
# Mean lives saved non-xrisk: 44028.41171640347
# Percentiles: {1: 0.0, 5: 0.0, 10: 0.0, 20: 0.0, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.0, 90: 0.0, 95: 0.0, 99: 0.0}
# Mean DALYs saved approx if prevent risk: 436243230623812.2
# Expected DALYs saved: 5441228528.844002
# Percentiles Expected DALYs saved: {1: -3636979759.5760584, 5: -1256324230.4648366, 10: -528368951.0772736, 20: 0.0, 30: 0.0, 40: 1012797170.3491236, 50: 2867440668.1668606, 60: 4566222248.181268, 70: 6624230692.456686, 80: 9563004922.570993, 90: 14993924725.003592, 95: 21117666201.21418, 99: 38665281902.01861}
# Prop. time intervention affects risk: 0.800008375
# Mean effect size (per $100000000 spent): 1.2470548098188457e-05
# Mean absolute effect size: 1.3392206428279955e-05
# Approx number makes a difference: 107.13765142623964
# Obeserved number makes a difference: 92.0
# Chance prevents extinction: 0.0011%
# Chance causes extinction: 5e-05%
# Chance make a difference: 0.00115%
# AVG DALYs saved (per $100000000 spent):
# Avg. DALYs saved per $1000: 41183.241308588134
# Percentiles:
# [-1.45452931e+05 -1.15436122e+04  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.16389426e+04  9.81881505e+08]
# Expected DALYs saved per $1000: 54412.28528843996
# Percentiles:
# [-588342.58806007 -345072.8125071  -192193.870226    -94564.82053
#   -36369.8012      -12563.2405       28674.405       211176.66
#   386652.821       742072.93259002 1249771.160126   1898997.11182878]

# %% [markdown]
# #### Longterm "Risky" Intervention

# %%
## Riskier intervention with a long impact
lt_risky_xrisk_intervention = {'p_has_effect': 0.5, 
                    'p_good_if_effect': 0.55, 
                    'low_extent_of_negative_effect': 0.3, 
                    'high_extent_of_negative_effect': 1.0, 
                    'low_years_credit': 10*K, 
                    'high_years_credit': 100*K, 
                    'low_amt_risk_reduced_per_B': bp_to_decimal(5), 
                    'high_amt_risk_reduced_per_B': bp_to_decimal(50),
                    'cost': 100*M,
                    'low_years_between_events_killing_3M': 129,
                    'high_years_between_events_killing_3M': 523,} 

lt_risky_xrisk_dalys_per_1000, lt_risky_risk_reduction_vector, lt_risky_e_reduction_risk, lt_risky_p_save_world, \
    lt_risky_p_end_world, lt_risky_dalys_at_stake, lt_risky_expected_dalys_saved_per_1000 = xrisk.get_dalys_saved_per_1000(lt_risky_xrisk_intervention, to_print=True)
# Out:
# Mean effect multiplier: 0.14507407353568996
# Percentiles:
# {1: -1.0, 5: -0.7247262178411366, 10: -0.5763436275109438, 20: -0.35046694497450664, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 1.0, 90: 1.0, 95: 1.0, 99: 1.0}
# Mean years credit: 200.0
# Percentiles:
# {1: 200.0, 5: 200.0, 10: 200.0, 20: 200.0, 30: 200.0, 40: 200.0, 50: 200.0, 60: 200.0, 70: 200.0, 80: 200.0, 90: 200.0, 95: 200.0, 99: 200.0}
# 3M to 30M
# Mean pre-intervention annual probability of event: 0.003003259212879676
# Mean pre-intervention cumulative probability of event: 0.4336226144885893
# Mean post-intervention annual probability of event: 0.003002161703212804
# Mean post-intervention cumulative probability of event: 0.4335106537961098
# Mean decrease in cumulative probability of event: 0.00011196069247923544
# Percentiles:
# {1: -0.0010522092913731406, 5: -0.0005948999161071722, 10: -0.0004021936344071997, 20: -0.00016850145471325462, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.0004912371860712251, 90: 0.0008110047489011232, 95: 0.0010837248042017075, 99: 0.0017077184227495454}
# 30M to 300M
# Mean pre-intervention annual probability of event: 0.0008496099627576829
# Mean pre-intervention cumulative probability of event: 0.1538125321803564
# Mean post-intervention annual probability of event: 0.000849299191258131
# Mean post-intervention cumulative probability of event: 0.15376166452535028
# Mean decrease in cumulative probability of event: 5.0867655006135335e-05
# Percentiles:
# {1: -0.0005175388986737872, 5: -0.00027245062480655836, 10: -0.00017590633301819424, 20: -6.670396640691134e-05, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.00020163636227812367, 90: 0.00036242564726087786, 95: 0.0005084560367320689, 99: 0.0008631211194000173}
# 300M to 3B
# Mean pre-intervention annual probability of event: 0.00024990202108394354
# Mean pre-intervention cumulative probability of event: 0.048391503293570365
# Mean post-intervention annual probability of event: 0.00024988736465409
# Mean post-intervention cumulative probability of event: 0.048388755953645446
# Mean decrease in cumulative probability of event: 2.747339924842094e-06
# Percentiles:
# {1: -3.4458548740130545e-05, 5: -1.4546496716877354e-05, 10: -8.132682276762449e-06, 20: -2.2711439628508854e-06, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 7.748082657910162e-06, 90: 1.7721505509316076e-05, 95: 2.8724130530521916e-05, 99: 6.120818325914596e-05}
# Number 3M to 30M where difference made: 2560.0
# Number 30M to 300M where difference made: 1153.0
# Number 300M to 3B where difference made: 69.0
# Total 3M to 30M prevented 1720.0
# Total 30M to 300M prevented 768.0
# Total 300M to 3B prevented 43.0
# Total 3M to 30M caused 840.0
# Total 30M to 300M caused 385.0
# Total 300M to 3B caused 26.0
# Mean lives saved non-xrisk: 8275.463603329239
# Percentiles: {1: 0.0, 5: 0.0, 10: 0.0, 20: 0.0, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.0, 90: 0.0, 95: 0.0, 99: 0.0}
# Mean DALYs saved approx if prevent risk: 436349482169501.3
# Expected DALYs saved: 12779640688.836191
# Percentiles Expected DALYs saved: {1: -163185089113.35825, 5: -69555868861.21562, 10: -38398154899.34283, 20: -8350803455.25646, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 34357432265.578873, 90: 84632966738.3673, 95: 137557669790.4254, 99: 288448626696.8741}
# Prop. time intervention affects risk: 0.499970125
# Mean effect size (per $100000000 spent): 2.9322034582935086e-05
# Mean absolute effect size: 8.180191639122617e-05
# Approx number makes a difference: 654.4153311298094
# Obeserved number makes a difference: 667.0
# Chance prevents extinction: 0.005375%
# Chance causes extinction: 0.0029625%
# Chance make a difference: 0.0083375%
# AVG DALYs saved (per $100000000 spent):
# Avg. DALYs saved per $1000: 91460.3914966399
# Percentiles:
# [-8.53617152e+09 -5.48358956e+09 -7.86610343e+03  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  4.65413052e+04  6.22623213e+09]
# Expected DALYs saved per $1000: 127796.40688836187
# Percentiles:
# [-16226940.44643997 -10619499.0602028   -6487277.760046
#   -3627208.75184     -1631850.8944       -695558.686
#          0.           1375576.7005       2884486.2658
#    5907557.61784003  10228179.72032074  16135727.98689268]

# %% [markdown]
# #### Chickens + Global Health Interventions

# %%
chickens_human_dalys_per_1000 = chickens.chicken_campaign_human_dalys_per_1000()
chickens_sc_human_dalys_per_1000 = chickens.sample_sc_human_eq_dalys_per_1000_chicken_campaign(moral_weight_lims=None)

chicken_human_daly_burden = sq.sample(sq.lognorm(306*M, 34.5*B), N)

print("Sentience-conditioned human-equivalent DALYs per 1000 chickens")
print(sq.get_percentiles(chickens_sc_human_dalys_per_1000))
print(np.mean(chickens_sc_human_dalys_per_1000))

print("Sentience-adjusted human-equivalent DALYs per 1000 chickens")
print(sq.get_percentiles(chickens_human_dalys_per_1000))
print(np.mean(chickens_human_dalys_per_1000))
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:03<00:00,  1.68s/it]
# 100%|██████████| 8000000/8000000 [00:15<00:00, 517241.27it/s]
# 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# 100%|██████████| 8000000/8000000 [00:13<00:00, 606862.52it/s]
# Sentience-conditioned human-equivalent DALYs per 1000 chickens
# {1: -590.9487508639655, 5: 70.1481817911902, 10: 136.42157199056766, 20: 248.86578134389003, 30: 369.1669332512226, 40: 511.2112116592217, 50: 689.6003893711545, 60: 927.0785618876985, 70: 1269.3263559882823, 80: 1826.460423182085, 90: 3013.249485652843, 95: 4534.857655071754, 99: 9616.066027541312}
# 1293.636600432626
# Sentience-adjusted human-equivalent DALYs per 1000 chickens
# {1: -509.68039174149453, 5: 0.0, 10: 0.0, 20: 118.48254127940078, 30: 247.93437052993767, 40: 387.06352517383283, 50: 557.0163489662316, 60: 781.5081404527856, 70: 1104.7570942554657, 80: 1631.7190572827133, 90: 2758.611322176508, 95: 4207.922361878952, 99: 9090.057381589888}
# 1130.4780717497222

# %% [markdown]
# #### Global Health

# %%
amf_dalys_per_1000 = low_risk_ghd.amf_dalys_per_1000()
road_safety_dalys_per_1000 = road_safety.get_failure_adjusted_dalys_per_1000()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:10<00:00,  5.23s/it]
# 100%|██████████| 8000000/8000000 [00:12<00:00, 659993.54it/s]

# %% [markdown]
# #### Results

# %%
causes = ['Shrimp - Stunning', 'Shrimp - Ammonia', 'Chickens', 'Nearterm conservative X-risk', "Nearterm risky X-risk", \
          'Longterm conservative X-risk', 'Longterm risky X-risk', 
           'Against Malaria', 'Road Safety']

# DALYs per $1000 for each cause stored in a dictionary
results_dict = {'Shrimp - Stunning': shrimp_stunning_human_dalys_per_1000, 
                'Shrimp - Ammonia': shrimp_nh3_human_dalys_per_1000, 
                'Chickens': chickens_human_dalys_per_1000,
                'Nearterm conservative X-risk': nt_conservative_xrisk_dalys_per_1000,
                'Nearterm risky X-risk': nt_risky_xrisk_dalys_per_1000,
                'Longterm conservative X-risk': lt_conservative_xrisk_dalys_per_1000,    
                'Longterm risky X-risk': lt_risky_xrisk_dalys_per_1000,  
                'Against Malaria': amf_dalys_per_1000,
                'Road Safety': road_safety_dalys_per_1000}

ev_results_dict = {'Shrimp - Stunning': shrimp_stunning_human_dalys_per_1000, 
                'Shrimp - Ammonia': shrimp_nh3_human_dalys_per_1000, 
                'Chickens': chickens_human_dalys_per_1000,
                'Nearterm conservative X-risk': nt_conservative_expected_dalys_saved_per_1000,
                'Nearterm risky X-risk': nt_risky_expected_dalys_saved_per_1000,
                'Longterm conservative X-risk': lt_conservative_expected_dalys_saved_per_1000,    
                'Longterm risky X-risk': lt_risky_expected_dalys_saved_per_1000,
                'Against Malaria': amf_dalys_per_1000,
                'Road Safety': road_safety_dalys_per_1000}

# %% [markdown]
# ## Expected Value Comparison

# %%
ev_df = utils.make_ev_dataframe(results_dict, causes, 'full_output')
print(ev_df)
# Out:
#                               Mean DALYs/$1000  0.15th-pct  1st-pct  5th-pct  \
# Shrimp - Stunning                        37.70      -17.66     0.00     0.00
# Shrimp - Ammonia                       1475.96    -1522.42    -6.30     0.00
# Chickens                               1130.48    -2147.48  -509.68     0.00
# Nearterm conservative X-risk            634.93        0.00     0.00     0.00
# Nearterm risky X-risk                  1420.17        0.00     0.00     0.00
# Longterm conservative X-risk          41183.24        0.00     0.00     0.00
# Longterm risky X-risk                 91460.39        0.00     0.00     0.00
# Against Malaria                          19.06       -9.52    -6.95    13.48
# Road Safety                              18.12        0.00     0.00     0.00
#
#                               25th-pct  50th-pct  75th-pct  95th-pct  \
# Shrimp - Stunning                 0.00      0.00      7.15    144.05
# Shrimp - Ammonia                  0.00      0.00     57.85   2857.35
# Chickens                        184.12    557.02   1330.61   4207.92
# Nearterm conservative X-risk      0.00      0.00      0.00      0.00
# Nearterm risky X-risk             0.00      0.00      0.00      0.00
# Longterm conservative X-risk      0.00      0.00      0.00      0.00
# Longterm risky X-risk             0.00      0.00      0.00      0.00
# Against Malaria                  16.54     18.90     21.94     28.44
# Road Safety                       0.00      0.00      0.00     94.12
#
#                               99th-pct  99.85th-pct
# Shrimp - Stunning               699.19      2517.82
# Shrimp - Ammonia              23105.76    138810.95
# Chickens                       9090.06     18281.11
# Nearterm conservative X-risk      0.00         0.00
# Nearterm risky X-risk             0.00         0.00
# Longterm conservative X-risk      0.00         0.00
# Longterm risky X-risk             0.00         0.00
# Against Malaria                  33.33        33.33
# Road Safety                     129.04       168.35

# %% [markdown]
# ## Difference-Making Risk-weighted Utility Comparison

# %% [markdown]
# ### Calibration

# %%
#a_user = dmreu_calibration.user_dmreu_level()
a_user = 0.05

# %% [markdown]
# ### Calculations -- Difference Making with Respect to Preventing Existential and Non-Existential Catastrophes

# %%
dmreu_prevent_xrisk_df = utils.make_dmreu_dataframe(results_dict, causes, a_user, 'Preventing_xrisk')
print(dmreu_prevent_xrisk_df)
# Out:
#                               p = 0.01   p = 0.02   p = 0.03   p = 0.04  \
# Shrimp - Stunning                37.70      20.24      13.26       9.46
# Shrimp - Ammonia               1475.96     609.36     331.86     201.05
# Chickens                       1130.48     871.70     734.76     643.47
# Nearterm conservative X-risk    634.93      40.45     -34.19     -52.57
# Nearterm risky X-risk          1420.17    -968.45   -1447.92   -1660.83
# Longterm conservative X-risk  41183.24     989.88   -3861.55   -5109.08
# Longterm risky X-risk         91460.39 -123688.44 -169920.09 -192305.26
# Against Malaria                  19.06      18.29      17.80      17.43
# Road Safety                      18.12      13.32      10.59       8.72
#
#                                p = 0.05   p = 0.07   p = 0.10
# Shrimp - Stunning                  7.08       4.29       2.20
# Shrimp - Ammonia                 127.12      48.94      -3.67
# Chickens                         575.76     478.37     380.60
# Nearterm conservative X-risk     -60.30     -69.45     -80.41
# Nearterm risky X-risk          -1808.31   -2047.99   -2366.92
# Longterm conservative X-risk   -5701.04   -6500.25   -7515.70
# Longterm risky X-risk        -208663.15 -235986.99 -272682.36
# Against Malaria                   17.13      16.65      16.08
# Road Safety                        7.33       5.36       3.51

# %% [markdown]
# ## Ambiguity Aversion

# %% [markdown]
# #### Calculations -- Difference-Making with Respect to Lowering the Probability of Extinction

# %%
import risk_models.ambiguity_aversion as aa
import os
aaev_lower_p_xrisk_df = aa.make_aaev_dataframe(ev_results_dict, causes, folder='results', path = 'ambiguity_aversion', to_print=False)
print(aaev_lower_p_xrisk_df)
# Out:
#                               No ambiguity aversion  \
# Longterm risky X-risk                 127796.406888
# Longterm conservative X-risk           54412.285288
# Shrimp - Ammonia                        1475.964296
# Nearterm risky X-risk                   1282.642417
# Chickens                                1130.478072
# Nearterm conservative X-risk             561.498871
# Shrimp - Stunning                         37.697906
# Against Malaria                           19.062820
# Road Safety                               18.123817
#
#                               Cubic, 1.5x weight to worst  \
# Longterm risky X-risk                         5015.978182
# Longterm conservative X-risk                 40865.014132
# Shrimp - Ammonia                               770.198062
# Nearterm risky X-risk                           53.145120
# Chickens                                       854.976462
# Nearterm conservative X-risk                   423.977010
# Shrimp - Stunning                               21.764039
# Against Malaria                                 17.997595
# Road Safety                                     12.982346
#
#                               Cubic, 2x weight to worst       1st-pct  \
# Longterm risky X-risk                    -117764.450525 -1.631851e+06
# Longterm conservative X-risk               27317.742976 -3.636980e+04
# Shrimp - Ammonia                              64.431827 -6.302626e+00
# Nearterm risky X-risk                      -1176.352178 -1.628693e+04
# Chickens                                     579.474852 -5.096804e+02
# Nearterm conservative X-risk                 286.455149 -3.695011e+02
# Shrimp - Stunning                              5.830171  0.000000e+00
# Against Malaria                               16.932371 -6.953030e+00
# Road Safety                                    7.840876  0.000000e+00
#
#                                     5th-pct    25th-pct        Median  \
# Longterm risky X-risk        -695558.688612    0.000000      0.000000
# Longterm conservative X-risk  -12563.242305    0.000000  28674.406682
# Shrimp - Ammonia                   0.000000    0.000000      0.000000
# Nearterm risky X-risk          -6963.727656    0.000000      0.000000
# Chickens                           0.000000  184.117458    557.016349
# Nearterm conservative X-risk    -130.130999    0.000000    315.349456
# Shrimp - Stunning                  0.000000    0.000000      0.000000
# Against Malaria                   13.475871   16.537536     18.899963
# Road Safety                        0.000000    0.000000      0.000000
#
#                                    75th-pct      95th-pct      99th-pct
# Longterm risky X-risk         141946.628172  1.375577e+06  2.884486e+06
# Longterm conservative X-risk   79343.090189  2.111767e+05  3.866528e+05
# Shrimp - Ammonia                  57.845332  2.857355e+03  2.310576e+04
# Nearterm risky X-risk           1441.562724  1.376979e+04  2.882301e+04
# Chickens                        1330.614582  4.207922e+03  9.090057e+03
# Nearterm conservative X-risk     823.993158  2.143185e+03  3.893971e+03
# Shrimp - Stunning                  7.149290  1.440532e+02  6.991938e+02
# Against Malaria                   21.942116  2.843800e+01  3.333333e+01
# Road Safety                        0.000000  9.411537e+01  1.290391e+02

# %% [markdown]
# ## Weighted Linear Utility

# %%
import helper_functions.utils as utils

wlu_df = utils.make_wlu_dataframe(results_dict, causes, 0.05, 'full_output', money_spent=money)
print(wlu_df)
# Out:
#                                      c = 0       c = 0.01       c = 0.05  \
# Shrimp - Stunning                37.697906      21.387689      14.442393
# Shrimp - Ammonia               1475.964296     789.237266     437.846316
# Chickens                       1130.478072     890.002466     688.971821
# Nearterm conservative X-risk    634.932799     225.659963      55.074758
# Nearterm risky X-risk          1420.168459    -748.675692   -1655.353164
# Longterm conservative X-risk  41183.241309   12754.352157      50.638341
# Longterm risky X-risk         91460.391497 -121154.006198 -216106.668643
# Against Malaria                  19.062820      17.398586      16.233996
# Road Safety                      18.123817       9.583464       6.753293
#
#                                    c = 0.10       c = 0.15       c = 0.25
# Shrimp - Stunning                  7.462102       3.252583       0.126954
# Shrimp - Ammonia                 141.832644       5.826871     -65.483877
# Chickens                         382.015141     112.898864    -138.875115
# Nearterm conservative X-risk     -43.249770     -71.307047     -79.937722
# Nearterm risky X-risk          -2174.560639   -2320.890699   -2364.949562
# Longterm conservative X-risk   -5924.068732   -7218.622362   -7510.895263
# Longterm risky X-risk        -260792.257974 -270479.513289 -272666.396705
# Against Malaria                   13.834334      10.189164       1.277743
# Road Safety                        3.834251       1.960540       0.438794

# %% [markdown]
# ## Risk-weighted Expected Utility with Respect to States of the World

# %% [markdown]
# ### Long-term Counterfactual Impacts Models

# %%
import risk_models.reu as reu
import importlib
importlib.reload(reu)

longterm_inputs = amf_dalys_per_1000, chickens_sc_human_dalys_per_1000, shrimp_stunning_human_dalys_per_1000, \
            shrimp_nh3_sentience_conditioned_human_dalys_per_1000, shrimp_sc_stunning_human_daly_burden, shrimp_sc_nh3_human_daly_burden, \
            chicken_human_daly_burden, lt_conservative_risk_reduction_vector, lt_risky_risk_reduction_vector, lt_conservative_dalys_at_stake

lt_reu_df_risk_neutral, lt_changes_in_reu_df_risk_neutral, lt_prop_time_best_action_risk_neutral, lt_ratio_change_reu_risk_neutral, \
    lt_reu_df_risk_averse, lt_changes_in_reu_df_risk_averse, lt_prop_time_best_action_risk_averse, lt_ratio_change_reu_risk_averse \
    = reu.reu_main(a_user, longterm_inputs, "longterm")

# %% [markdown]
# #### Longterm Impacts -- REU Under Risk Neutrality

# %%
print("Risk neutral REU")
print("Averages")
print(lt_reu_df_risk_neutral)
print("Changes")
print(lt_changes_in_reu_df_risk_neutral)
print("Proportion of time best action")
print(lt_prop_time_best_action_risk_neutral)
print("Ratios of average changes in REU by cause")
print("Cause in the row increased REU over doing nothing by X times as much as the cause in the column increased REU over doing nothing")
print(lt_ratio_change_reu_risk_neutral)
# Out:
# Risk neutral REU
# Averages
#                             Mean, a = 1  \
# Risky x-risk work         -5.497341e+13
# Conservative x-risk work  -5.497415e+13
# CF campaign               -5.497458e+13
# Shrimp welfare - NH3      -5.497465e+13
# AMF                       -5.497469e+13
# Shrimp welfare - stunning -5.497469e+13
# Nothing                   -5.497469e+13
#
#                            Ambiguity averse, 1.5x weight to worst  \
# Risky x-risk work                                   -6.237432e+13
# Conservative x-risk work                            -6.237511e+13
# CF campaign                                         -6.237559e+13
# Shrimp welfare - NH3                                -6.237565e+13
# AMF                                                 -6.237569e+13
# Shrimp welfare - stunning                           -6.237570e+13
# Nothing                                             -6.237570e+13
#
#                            Ambiguity averse, 2x weight to worst  \
# Risky x-risk work                                 -6.977523e+13
# Conservative x-risk work                          -6.977608e+13
# CF campaign                                       -6.977659e+13
# Shrimp welfare - NH3                              -6.977666e+13
# AMF                                               -6.977670e+13
# Shrimp welfare - stunning                         -6.977670e+13
# Nothing                                           -6.977670e+13
#
#                            fifth percentile  ninety fifth percentile  \
# Risky x-risk work             -1.370361e+14            -6.901094e+12
# Conservative x-risk work      -1.370358e+14            -6.901095e+12
# CF campaign                   -1.370367e+14            -6.901207e+12
# Shrimp welfare - NH3          -1.370368e+14            -6.901229e+12
# AMF                           -1.370368e+14            -6.901332e+12
# Shrimp welfare - stunning     -1.370368e+14            -6.901334e+12
# Nothing                       -1.370368e+14            -6.901334e+12
#
#                                  median
# Risky x-risk work         -4.466267e+13
# Conservative x-risk work  -4.466341e+13
# CF campaign               -4.466375e+13
# Shrimp welfare - NH3      -4.466383e+13
# AMF                       -4.466386e+13
# Shrimp welfare - stunning -4.466386e+13
# Nothing                   -4.466386e+13
# Changes
#                             Mean, a = 1  \
# Risky x-risk work          1.279803e+09
# Conservative x-risk work   5.439413e+08
# CF campaign                1.088511e+08
# Shrimp welfare - NH3       4.273817e+07
# AMF                        1.906282e+06
# Shrimp welfare - stunning  8.549467e+05
# Nothing                    0.000000e+00
#
#                            Ambiguity averse, 1.5x weight to worst  \
# Risky x-risk work                                    5.231885e+07
# Conservative x-risk work                             4.084888e+08
# CF campaign                                          8.492952e+07
# Shrimp welfare - NH3                                 2.453616e+07
# AMF                                                  1.799760e+06
# Shrimp welfare - stunning                            5.096355e+05
# Nothing                                              0.000000e+00
#
#                            Ambiguity averse, 2x weight to worst  \
# Risky x-risk work                                 -1.175166e+09
# Conservative x-risk work                           2.730364e+08
# CF campaign                                        6.100790e+07
# Shrimp welfare - NH3                               6.334143e+06
# AMF                                                1.693237e+06
# Shrimp welfare - stunning                          1.643243e+05
# Nothing                                            0.000000e+00
#
#                            fifth percentile  ninety fifth percentile  \
# Risky x-risk work             -6.956382e+09             1.374916e+10
# Conservative x-risk work      -1.255858e+08             2.111449e+09
# CF campaign                    6.077269e+06             3.791221e+08
# Shrimp welfare - NH3           2.503280e+04             1.683464e+08
# AMF                            1.347587e+06             2.843800e+06
# Shrimp welfare - stunning      0.000000e+00             3.892349e+06
# Nothing                        0.000000e+00             0.000000e+00
#
#                                  median
# Risky x-risk work          0.000000e+00
# Conservative x-risk work   2.864384e+08
# CF campaign                5.978066e+07
# Shrimp welfare - NH3       4.025941e+06
# AMF                        1.889996e+06
# Shrimp welfare - stunning  0.000000e+00
# Nothing                    0.000000e+00
# Proportion of time best action
#                            Proportion of time best action
# Nothing                                          0.000005
# AMF                                              0.002832
# CF campaign                                      0.252998
# Shrimp welfare - stunning                        0.001114
# Shrimp welfare - NH3                             0.051985
# Conservative x-risk work                         0.420996
# Risky x-risk work                                0.270070
# Ratios of average changes in REU by cause
# Cause in the row increased REU over doing nothing by X times as much as the cause in the column increased REU over doing nothing
#                                   AMF  CF campaign  Shrimp welfare - stunning  \
# AMF                          1.000000     0.017513                   2.229708
# CF campaign                 57.101282     1.000000                 127.319214
# Shrimp welfare - stunning    0.448489     0.007854                   1.000000
# Shrimp welfare - NH3        22.419648     0.392630                  49.989281
# Conservative x-risk work   285.341486     4.997112                 636.228335
# Risky x-risk work          671.361019    11.757372                1496.939368
#
#                            Shrimp welfare - NH3  Conservative x-risk work  \
# AMF                                    0.044604                  0.003505
# CF campaign                            2.546930                  0.200116
# Shrimp welfare - stunning              0.020004                  0.001572
# Shrimp welfare - NH3                   1.000000                  0.078571
# Conservative x-risk work              12.727295                  1.000000
# Risky x-risk work                     29.945207                  2.352834
#
#                            Risky x-risk work
# AMF                                 0.001490
# CF campaign                         0.085053
# Shrimp welfare - stunning           0.000668
# Shrimp welfare - NH3                0.033394
# Conservative x-risk work            0.425019
# Risky x-risk work                   1.000000

# %% [markdown]
# #### Longterm Impacts -- REU with Specified Risk Aversion Level

# %%
print("Risk averse REU")
print("Averages")
print(lt_reu_df_risk_averse)
print("Changes")
print(lt_changes_in_reu_df_risk_averse)
print("Proportion of time best action")
print(lt_prop_time_best_action_risk_averse)
print("Ratios of average changes in REU by cause")
print("Cause in the row increased REU over doing nothing by X times as much as the cause in the column increased REU over doing nothing")
print(lt_ratio_change_reu_risk_averse)
# Out:
# Risk averse REU
# Averages
#                            Mean, a = 1.54  \
# Risky x-risk work           -8.075892e+13
# Conservative x-risk work    -8.075997e+13
# CF campaign                 -8.076063e+13
# Shrimp welfare - NH3        -8.076069e+13
# AMF                         -8.076075e+13
# Shrimp welfare - stunning   -8.076075e+13
# Nothing                     -8.076075e+13
#
#                            Ambiguity averse, 1.5x weight to worst  \
# Risky x-risk work                                   -9.138386e+13
# Conservative x-risk work                            -9.138499e+13
# CF campaign                                         -9.138570e+13
# Shrimp welfare - NH3                                -9.138577e+13
# AMF                                                 -9.138582e+13
# Shrimp welfare - stunning                           -9.138582e+13
# Nothing                                             -9.138582e+13
#
#                            Ambiguity averse, 2x weight to worst  \
# Risky x-risk work                                 -1.020088e+14
# Conservative x-risk work                          -1.020100e+14
# CF campaign                                       -1.020108e+14
# Shrimp welfare - NH3                              -1.020108e+14
# AMF                                               -1.020109e+14
# Shrimp welfare - stunning                         -1.020109e+14
# Nothing                                           -1.020109e+14
#
#                            fifth percentile  ninety fifth percentile  \
# Risky x-risk work             -1.982234e+14            -1.035352e+13
# Conservative x-risk work      -1.982246e+14            -1.035420e+13
# CF campaign                   -1.982252e+14            -1.035430e+13
# Shrimp welfare - NH3          -1.982252e+14            -1.035430e+13
# AMF                           -1.982252e+14            -1.035437e+13
# Shrimp welfare - stunning     -1.982252e+14            -1.035437e+13
# Nothing                       -1.982252e+14            -1.035437e+13
#
#                                  median
# Risky x-risk work         -6.652627e+13
# Conservative x-risk work  -6.652735e+13
# CF campaign               -6.652792e+13
# Shrimp welfare - NH3      -6.652809e+13
# AMF                       -6.652815e+13
# Shrimp welfare - stunning -6.652815e+13
# Nothing                   -6.652815e+13
# Changes
#                            Mean, a = 1.54  \
# Risky x-risk work            1.828511e+09
# Conservative x-risk work     7.772045e+08
# CF campaign                  1.161955e+08
# Shrimp welfare - NH3         5.268371e+07
# AMF                          1.906282e+06
# Shrimp welfare - stunning    1.044403e+06
# Nothing                      0.000000e+00
#
#                            Ambiguity averse, 1.5x weight to worst  \
# Risky x-risk work                                    7.396773e+07
# Conservative x-risk work                             5.835263e+08
# CF campaign                                          9.068525e+07
# Shrimp welfare - NH3                                 3.022867e+07
# AMF                                                  1.799760e+06
# Shrimp welfare - stunning                            6.236052e+05
# Nothing                                              0.000000e+00
#
#                            Ambiguity averse, 2x weight to worst  \
# Risky x-risk work                                 -1.680575e+09
# Conservative x-risk work                           3.898480e+08
# CF campaign                                        6.517500e+07
# Shrimp welfare - NH3                               7.773637e+06
# AMF                                                1.693237e+06
# Shrimp welfare - stunning                          2.028078e+05
# Nothing                                            0.000000e+00
#
#                            fifth percentile  ninety fifth percentile  \
# Risky x-risk work             -9.938084e+09             1.964635e+10
# Conservative x-risk work      -1.792913e+08             3.018199e+09
# CF campaign                    6.518763e+06             4.042876e+08
# Shrimp welfare - NH3           3.137571e+04             2.072290e+08
# AMF                            1.347587e+06             2.843800e+06
# Shrimp welfare - stunning      0.000000e+00             4.784878e+06
# Nothing                        0.000000e+00             0.000000e+00
#
#                                  median
# Risky x-risk work          0.000000e+00
# Conservative x-risk work   4.085931e+08
# CF campaign                6.390053e+07
# Shrimp welfare - NH3       4.988738e+06
# AMF                        1.889996e+06
# Shrimp welfare - stunning  0.000000e+00
# Nothing                    0.000000e+00
# Proportion of time best action
#                            Proportion of time best action
# Nothing                                          0.000005
# AMF                                              0.002531
# CF campaign                                      0.240119
# Shrimp welfare - stunning                        0.001271
# Shrimp welfare - NH3                             0.054605
# Conservative x-risk work                         0.430709
# Risky x-risk work                                0.270760
# Ratios of average changes in REU by cause
# Cause in the row increased REU over doing nothing by X times as much as the cause in the column increased REU over doing nothing
#                                   AMF  CF campaign  Shrimp welfare - stunning  \
# AMF                          1.000000     0.016406                   1.825237
# CF campaign                 60.953988     1.000000                 111.255459
# Shrimp welfare - stunning    0.547874     0.008988                   1.000000
# Shrimp welfare - NH3        27.636893     0.453406                  50.443873
# Conservative x-risk work   407.707023     6.688767                 744.161837
# Risky x-risk work          959.202722    15.736505                1750.772051
#
#                            Shrimp welfare - NH3  Conservative x-risk work  \
# AMF                                    0.036184                  0.002453
# CF campaign                            2.205530                  0.149504
# Shrimp welfare - stunning              0.019824                  0.001344
# Shrimp welfare - NH3                   1.000000                  0.067786
# Conservative x-risk work              14.752274                  1.000000
# Risky x-risk work                     34.707328                  2.352676
#
#                            Risky x-risk work
# AMF                                 0.001043
# CF campaign                         0.063547
# Shrimp welfare - stunning           0.000571
# Shrimp welfare - NH3                0.028812
# Conservative x-risk work            0.425048
# Risky x-risk work                   1.000000

# %% [markdown]
# ### Near-term Counterfactual Impact Models

# %%
nearterm_inputs = amf_dalys_per_1000, chickens_sc_human_dalys_per_1000, shrimp_stunning_sentience_conditioned_human_dalys_per_1000, \
    shrimp_nh3_sentience_conditioned_human_dalys_per_1000, shrimp_sc_stunning_human_daly_burden, shrimp_sc_nh3_human_daly_burden, \
    chicken_human_daly_burden, nt_conservative_risk_reduction_vector, nt_risky_risk_reduction_vector, nt_conservative_dalys_at_stake

nt_reu_df_risk_neutral, nt_changes_in_reu_df_risk_neutral, nt_prop_time_best_action_risk_neutral, nt_ratio_change_reu_risk_neutral, \
    nt_reu_df_risk_averse, nt_changes_in_reu_df_risk_averse, nt_prop_time_best_action_risk_averse, nt_ratio_change_reu_risk_averse \
    = reu.reu_main(a_user, nearterm_inputs, "nearterm")

# %% [markdown]
# #### Nearterm Impacts -- REU under Risk Neutrality

# %%
print("Risk averse REU")
print("Averages")
print(nt_reu_df_risk_neutral)
print("Changes")
print(nt_changes_in_reu_df_risk_neutral)
print("Proportion of time best action")
print(nt_prop_time_best_action_risk_neutral)
print("Ratios of average changes in REU by cause")
print("Cause in the row increased REU over doing nothing by X times as much as the cause in the column increased REU over doing nothing")
print(nt_ratio_change_reu_risk_neutral)
# Out:
# Risk averse REU
# Averages
#                             Mean, a = 1  \
# CF campaign               -5.608268e+11
# Shrimp welfare - NH3      -5.608927e+11
# Risky x-risk work         -5.609228e+11
# Conservative x-risk work  -5.609302e+11
# Shrimp welfare - stunning -5.609335e+11
# AMF                       -5.609337e+11
# Nothing                   -5.609356e+11
#
#                            Ambiguity averse, 1.5x weight to worst  \
# CF campaign                                         -6.350753e+11
# Shrimp welfare - NH3                                -6.351411e+11
# Risky x-risk work                                   -6.351704e+11
# Conservative x-risk work                            -6.351783e+11
# Shrimp welfare - stunning                           -6.351820e+11
# AMF                                                 -6.351822e+11
# Nothing                                             -6.351841e+11
#
#                            Ambiguity averse, 2x weight to worst  \
# CF campaign                                       -7.093238e+11
# Shrimp welfare - NH3                              -7.093895e+11
# Risky x-risk work                                 -7.094180e+11
# Conservative x-risk work                          -7.094265e+11
# Shrimp welfare - stunning                         -7.094306e+11
# AMF                                               -7.094308e+11
# Nothing                                           -7.094327e+11
#
#                            fifth percentile  ninety fifth percentile  \
# CF campaign                   -1.382824e+12            -7.849215e+10
# Shrimp welfare - NH3          -1.382865e+12            -7.855813e+10
# Risky x-risk work             -1.382898e+12            -7.859744e+10
# Conservative x-risk work      -1.382900e+12            -7.860029e+10
# Shrimp welfare - stunning     -1.382910e+12            -7.859783e+10
# AMF                           -1.382909e+12            -7.859959e+10
# Nothing                       -1.382911e+12            -7.860078e+10
#
#                                  median
# CF campaign               -4.577173e+11
# Shrimp welfare - NH3      -4.577830e+11
# Risky x-risk work         -4.578128e+11
# Conservative x-risk work  -4.578227e+11
# Shrimp welfare - stunning -4.578260e+11
# AMF                       -4.578261e+11
# Nothing                   -4.578282e+11
# Changes
#                             Mean, a = 1  \
# CF campaign                1.088361e+08
# Shrimp welfare - NH3       4.285652e+07
# Risky x-risk work          1.279973e+07
# Conservative x-risk work   5.442707e+06
# Shrimp welfare - stunning  2.131560e+06
# AMF                        1.906282e+06
# Nothing                    0.000000e+00
#
#                            Ambiguity averse, 1.5x weight to worst  \
# CF campaign                                          8.491882e+07
# Shrimp welfare - NH3                                 2.462615e+07
# Risky x-risk work                                    5.207189e+05
# Conservative x-risk work                             4.087952e+06
# Shrimp welfare - stunning                            1.450802e+06
# AMF                                                  1.799760e+06
# Nothing                                              0.000000e+00
#
#                            Ambiguity averse, 2x weight to worst  \
# CF campaign                                        6.100149e+07
# Shrimp welfare - NH3                               6.395775e+06
# Risky x-risk work                                 -1.175829e+07
# Conservative x-risk work                           2.733196e+06
# Shrimp welfare - stunning                          7.700440e+05
# AMF                                                1.693237e+06
# Nothing                                            0.000000e+00
#
#                            fifth percentile  ninety fifth percentile  \
# CF campaign                    6.074936e+06             3.790202e+08
# Shrimp welfare - NH3           2.505048e+04             1.685081e+08
# Risky x-risk work             -6.956347e+07             1.376774e+08
# Conservative x-risk work      -1.255652e+06             2.114103e+07
# Shrimp welfare - stunning      1.136875e+04             8.979901e+06
# AMF                            1.347587e+06             2.843800e+06
# Nothing                        0.000000e+00             0.000000e+00
#
#                                  median
# CF campaign                5.977493e+07
# Shrimp welfare - NH3       4.027275e+06
# Risky x-risk work          0.000000e+00
# Conservative x-risk work   2.864938e+06
# Shrimp welfare - stunning  4.653891e+05
# AMF                        1.889996e+06
# Nothing                    0.000000e+00
# Proportion of time best action
#                            Proportion of time best action
# Nothing                                      2.500000e-07
# AMF                                          3.115500e-03
# CF campaign                                  7.082404e-01
# Shrimp welfare - stunning                    6.688625e-03
# Shrimp welfare - NH3                         1.344856e-01
# Conservative x-risk work                     2.395225e-02
# Risky x-risk work                            1.235174e-01
# Ratios of average changes in REU by cause
# Cause in the row increased REU over doing nothing by X times as much as the cause in the column increased REU over doing nothing
#                                  AMF  CF campaign  Shrimp welfare - stunning  \
# AMF                         1.000000     0.017515                   0.894313
# CF campaign                57.093415     1.000000                  51.059378
# Shrimp welfare - stunning   1.118177     0.019585                   1.000000
# Shrimp welfare - NH3       22.481733     0.393771                  20.105704
# Conservative x-risk work    2.855143     0.050008                   2.553391
# Risky x-risk work           6.714501     0.117606                   6.004865
#
#                            Shrimp welfare - NH3  Conservative x-risk work  \
# AMF                                    0.044481                  0.350245
# CF campaign                            2.539547                 19.996694
# Shrimp welfare - stunning              0.049737                  0.391636
# Shrimp welfare - NH3                   1.000000                  7.874119
# Conservative x-risk work               0.126998                  1.000000
# Risky x-risk work                      0.298665                  2.351722
#
#                            Risky x-risk work
# AMF                                 0.148931
# CF campaign                         8.503002
# Shrimp welfare - stunning           0.166532
# Shrimp welfare - NH3                3.348236
# Conservative x-risk work            0.425220
# Risky x-risk work                   1.000000

# %% [markdown]
# #### Nearterm Impacts -- REU with Specified Risk Aversion Level

# %%
print("Risk averse REU")
print("Averages")
print(nt_reu_df_risk_averse)
print("Changes")
print(nt_changes_in_reu_df_risk_averse)
print("Proportion of time best action")
print(nt_prop_time_best_action_risk_averse)
print("Ratios of average changes in REU by cause")
print("Cause in the row increased REU over doing nothing by X times as much as the cause in the column increased REU over doing nothing")
print(nt_ratio_change_reu_risk_averse)
# Out:
# Risk averse REU
# Averages
#                            Mean, a = 1.54  \
# CF campaign                 -8.201859e+11
# Shrimp welfare - NH3        -8.202492e+11
# Risky x-risk work           -8.202838e+11
# Conservative x-risk work    -8.202943e+11
# Shrimp welfare - stunning   -8.202994e+11
# AMF                         -8.203001e+11
# Nothing                     -8.203020e+11
#
#                            Ambiguity averse, 1.5x weight to worst  \
# CF campaign                                         -9.266597e+11
# Shrimp welfare - NH3                                -9.267229e+11
# Risky x-risk work                                   -9.267563e+11
# Conservative x-risk work                            -9.267676e+11
# Shrimp welfare - stunning                           -9.267733e+11
# AMF                                                 -9.267740e+11
# Nothing                                             -9.267759e+11
#
#                            Ambiguity averse, 2x weight to worst  \
# CF campaign                                       -1.033134e+12
# Shrimp welfare - NH3                              -1.033197e+12
# Risky x-risk work                                 -1.033229e+12
# Conservative x-risk work                          -1.033241e+12
# Shrimp welfare - stunning                         -1.033247e+12
# AMF                                               -1.033248e+12
# Nothing                                           -1.033250e+12
#
#                            fifth percentile  ninety fifth percentile  \
# CF campaign                   -1.995606e+12            -1.145791e+11
# Shrimp welfare - NH3          -1.995664e+12            -1.146369e+11
# Risky x-risk work             -1.995689e+12            -1.146865e+11
# Conservative x-risk work      -1.995702e+12            -1.146835e+11
# Shrimp welfare - stunning     -1.995709e+12            -1.146835e+11
# AMF                           -1.995711e+12            -1.146842e+11
# Nothing                       -1.995713e+12            -1.146868e+11
#
#                                  median
# CF campaign               -6.778694e+11
# Shrimp welfare - NH3      -6.779303e+11
# Risky x-risk work         -6.779723e+11
# Conservative x-risk work  -6.779785e+11
# Shrimp welfare - stunning -6.779850e+11
# AMF                       -6.779850e+11
# Nothing                   -6.779870e+11
# Changes
#                            Mean, a = 1.54  \
# CF campaign                  1.161859e+08
# Shrimp welfare - NH3         5.282736e+07
# Risky x-risk work            1.828501e+07
# Conservative x-risk work     7.774609e+06
# Shrimp welfare - stunning    2.603515e+06
# AMF                          1.906282e+06
# Nothing                      0.000000e+00
#
#                            Ambiguity averse, 1.5x weight to worst  \
# CF campaign                                          9.067849e+07
# Shrimp welfare - NH3                                 3.033711e+07
# Risky x-risk work                                    7.372797e+05
# Conservative x-risk work                             5.837935e+06
# Shrimp welfare - stunning                            1.776230e+06
# AMF                                                  1.799760e+06
# Nothing                                              0.000000e+00
#
#                            Ambiguity averse, 2x weight to worst  \
# CF campaign                                        6.517110e+07
# Shrimp welfare - NH3                               7.846860e+06
# Risky x-risk work                                 -1.681045e+07
# Conservative x-risk work                           3.901261e+06
# Shrimp welfare - stunning                          9.489458e+05
# AMF                                                1.693237e+06
# Nothing                                            0.000000e+00
#
#                            fifth percentile  ninety fifth percentile  \
# CF campaign                    6.520008e+06             4.043061e+08
# Shrimp welfare - NH3           3.139630e+04             2.073437e+08
# Risky x-risk work             -9.937177e+07             1.966699e+08
# Conservative x-risk work      -1.792889e+06             3.022234e+07
# Shrimp welfare - stunning      1.426230e+04             1.098059e+07
# AMF                            1.347587e+06             2.843800e+06
# Nothing                        0.000000e+00             0.000000e+00
#
#                                  median
# CF campaign                6.390083e+07
# Shrimp welfare - NH3       4.989638e+06
# Risky x-risk work          0.000000e+00
# Conservative x-risk work   4.084811e+06
# Shrimp welfare - stunning  5.776128e+05
# AMF                        1.889996e+06
# Nothing                    0.000000e+00
# Proportion of time best action
#                            Proportion of time best action
# Nothing                                      2.500000e-07
# AMF                                          2.515500e-03
# CF campaign                                  6.722202e-01
# Shrimp welfare - stunning                    7.325875e-03
# Shrimp welfare - NH3                         1.420836e-01
# Conservative x-risk work                     3.297987e-02
# Risky x-risk work                            1.428746e-01
# Ratios of average changes in REU by cause
# Cause in the row increased REU over doing nothing by X times as much as the cause in the column increased REU over doing nothing
#                                  AMF  CF campaign  Shrimp welfare - stunning  \
# AMF                         1.000000     0.016407                   0.732196
# CF campaign                60.948945     1.000000                  44.626550
# Shrimp welfare - stunning   1.365755     0.022408                   1.000000
# Shrimp welfare - NH3       27.712249     0.454680                  20.290787
# Conservative x-risk work    4.078415     0.066915                   2.986198
# Risky x-risk work           9.591975     0.157377                   7.023202
#
#                            Shrimp welfare - NH3  Conservative x-risk work  \
# AMF                                    0.036085                  0.245193
# CF campaign                            2.199350                 14.944272
# Shrimp welfare - stunning              0.049283                  0.334874
# Shrimp welfare - NH3                   1.000000                  6.794857
# Conservative x-risk work               0.147170                  1.000000
# Risky x-risk work                      0.346128                  2.351888
#
#                            Risky x-risk work
# AMF                                 0.104254
# CF campaign                         6.354160
# Shrimp welfare - stunning           0.142385
# Shrimp welfare - NH3                2.889108
# Conservative x-risk work            0.425190
# Risky x-risk work                   1.000000
